# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df['Country'].nunique()
# Out:
# 158

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df.drop(['Country','Happiness Rank'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0  Western Europe            7.587         0.03411                   1.39651
# 1  Western Europe            7.561         0.04884                   1.30232
# 2  Western Europe            7.527         0.03328                   1.32548
# 3  Western Europe            7.522         0.03880                   1.45900
# 4   North America            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
dfcor=df.corr()
dfcor
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(dfcor,annot=True,cmap='RdYlGn')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Region', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
cols=['Happiness Score','Standard Error',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual']

for i in cols:
    
    plt.subplots()
    sns.boxplot(data=df[i],x=df[i],orient='v')

# %% [markdown]
# The Boxplot shows that there are outliers present in the dataset

# %%
sns.pairplot(df)

# %%
#skewness
for i in cols:
    plt.figure()
    sns.distplot(df[i])

# %% [markdown]
# The standard Error', 'Family', 'Trust (Government Corruption), and 'Genorisity' has skewed distribution

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Region']=le.fit_transform(df['Region'])
df.head()
# Out:
#    Region  Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0       9            7.587         0.03411                   1.39651  1.34951
# 1       9            7.561         0.04884                   1.30232  1.40223
# 2       9            7.527         0.03328                   1.32548  1.36058
# 3       9            7.522         0.03880                   1.45900  1.33095
# 4       5            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# ...

# %% [markdown]
# ### Checking for Outliers

# %%
from scipy.stats import zscore
zscr=np.abs(zscore(df))

# %%
threshold=3
print(np.where(zscr>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %% [markdown]
# The Zscore shows that there are 9 rows with outliers

# %%
zscr[27][7]
# Out:
# 3.1646194851713774

# %%
zscr[155][9]
# Out:
# 3.2084304855119408

# %% [markdown]
# ### Removing Outliers

# %%
df_new= df[(zscr<3).all(axis=1)]
df_new.shape
# Out:
# (149, 10)

# %%
for i in cols:
    plt.figure()
    sns.distplot(df_new[i])

# %%
df=df_new
df.head()
# Out:
#    Region  Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0       9            7.587         0.03411                   1.39651  1.34951
# 1       9            7.561         0.04884                   1.30232  1.40223
# 2       9            7.527         0.03328                   1.32548  1.36058
# 3       9            7.522         0.03880                   1.45900  1.33095
# 4       5            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# ...

# %% [markdown]
# Reindexing columns

# %%
df = df.reindex(columns=['Happiness Score', 'Region', 'Standard Error',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual'])
df.head()
# Out:
#    Happiness Score  Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587       9         0.03411                   1.39651  1.34951
# 1            7.561       9         0.04884                   1.30232  1.40223
# 2            7.527       9         0.03328                   1.32548  1.36058
# 3            7.522       9         0.03880                   1.45900  1.33095
# 4            7.427       5         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# ...

# %%
##Assigning x and y values to pass to the model
x=df.iloc[:,1:]
x
# Out:
#      Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0         9         0.03411                   1.39651  1.34951
# 1         9         0.04884                   1.30232  1.40223
# 2         9         0.03328                   1.32548  1.36058
# 3         9         0.03880                   1.45900  1.33095
# 4         5         0.03553                   1.32629  1.32261
# ..      ...             ...                       ...      ...
# 150       8         0.05141                   0.46534  0.77115
# 151       8         0.04324                   0.25812  0.85188
# 152       7         0.03084                   0.31982  0.30285
# 154       8         0.03656                   0.28665  0.35386
# 156       8         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# ...

# %%
##Assigning the happiness score to y
y=df.iloc[:,0]
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.linear_model import Lasso, Ridge
from sklearn.svm import SVR

# %%
#splitting for training and testing
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=43)

# %%
def model(mod):
    mod.fit(x_test,y_test)
    ##mod.coef_
    pred=mod.predict(x_test)
    mod.score(x_train,y_train)
    print('\n\n')
    ##print('predicted', pred)
    ##print('actual:',y_test)
    rscr=r2_score(y_test,pred)
    print('r2score:',r2_score(y_test,pred))
    print('Mean squared error',mean_squared_error(y_test,pred))
    print('mean absolute error:',mean_absolute_error(y_test,pred))

# %%
#function for cross-validation
from sklearn.model_selection import cross_val_score
def crossval(mod):
    scores = cross_val_score(mod, x_train, y_train, scoring='r2', cv=5)
    print(scores)
    mean=scores.mean()
    print("Mean:",mean)

# %% [markdown]
# ### Linear Regression

# %%
lr=LinearRegression()
model(lr)
crossval(lr)
# Out:
# r2score: 0.9999999420965654
# Mean squared error 6.413707540729679e-08
# mean absolute error: 0.0002039735901556413
# [0.9999999  0.99999995 0.99999995 0.99999992 0.99999993]
# Mean: 0.9999999294080546

# %% [markdown]
# ### Lasso

# %%
lasso=Lasso(alpha=0.01)
model(lasso)
crossval(lasso)
# Out:
# r2score: 0.9866482263042902
# Mean squared error 0.014789169627969468
# mean absolute error: 0.08873844586468395
# [0.98623795 0.9871641  0.99343038 0.99140977 0.9804929 ]
# Mean: 0.9877470185983764

# %% [markdown]
# ### SVR

# %%
k=['linear','poly','rbf']
for i in k:
    print('SVR kernel:',i)
    print('\n')
    svr=SVR(kernel=i)
    model(svr)
    crossval(svr)
# Out:
# SVR kernel: linear
#
#
#
#
#
# r2score: 0.9966382916803089
# Mean squared error 0.003723615731716769
# mean absolute error: 0.04962078388836671
# [0.99651631 0.99746452 0.99738357 0.99687067 0.99542292]
# Mean: 0.9967315973213164
# SVR kernel: poly
#
#
#
#
#
# r2score: 0.8463094836999117
# Mean squared error 0.17023619240210378
# mean absolute error: 0.3245303935537126
# [0.63981244 0.78392772 0.8740075  0.89012583 0.82260866]
# Mean: 0.8020964289183661
# SVR kernel: rbf
#
#
#
#
#
# r2score: 0.4250236013198804
# Mean squared error 0.6368759451706087
# mean absolute error: 0.5825297971647885
# [0.76063285 0.77423712 0.85098536 0.86745678 0.84481221]
# Mean: 0.8196248638541416

# %%
#selecting linear regression

# %%
import joblib
joblib.dump(lr, 'Worldhappiness.obj')
# Out:
# ['Worldhappiness.obj']
